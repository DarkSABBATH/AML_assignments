# %% [markdown]
# <a href="https://colab.research.google.com/github/DarkSABBATH/AML_assignments/blob/main/assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#Plot true vs predicted prices
plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', lw=2)  # diagonal line
plt.xlabel("Actual Median House Value")
plt.ylabel("Predicted Median House Value")
plt.title("Actual vs Predicted Housing Prices")
plt.show()

# %%
# Residual plot: residuals vs predicted values
residuals = y_test - y_pred
plt.figure(figsize=(8,6))
sns.scatterplot(x=y_pred, y=residuals, alpha=0.5)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Predicted Median House Value")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
# 3. Feature coefficients (importance)
coef = model.coef_
features = X.columns

plt.figure(figsize=(10,6))
sns.barplot(x=features, y=coef)
plt.xticks(rotation=45)
plt.ylabel("Coefficient Value")
plt.title("Feature Coefficients in Linear Regression Model")
plt.show()
